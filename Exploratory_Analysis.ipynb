# %%
from __future__ import division #, print_function # Imports from __future__ since we're running Python 2
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
random_state = 10 # Ensure reproducible results
# %matplotlib inline
plt.style.use('classic')
plt.rc("figure", facecolor="white")

# %%
path_data = os.path.join(os.getcwd(),'NY_flights.csv')
data = pd.read_csv(path_data, delimiter = ',')

# %%
print(plt.style.available)
# Out:
# ['seaborn-darkgrid', 'bmh', 'seaborn-pastel', 'dark_background', 'seaborn', 'seaborn-white', 'ggplot', 'seaborn-whitegrid', 'seaborn-dark-palette', 'classic', 'seaborn-notebook', 'seaborn-ticks', 'seaborn-bright', 'seaborn-talk', 'seaborn-dark', 'grayscale', 'seaborn-colorblind', 'fivethirtyeight', 'seaborn-paper', 'seaborn-deep', 'seaborn-poster', 'seaborn-muted']

# %%
print("There are {} entries and {} columns in the flight data"\
      .format(data.shape[0], data.shape[1]))
# Out:
# There are 481662 entries and 30 columns in the flight data

# %%
data.head(5)
# Out:
#    Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0           0        1      1             4            1  2016-01-04
# 1           1        1      1             4            1  2016-01-04
# 2           2        1      1             4            1  2016-01-04
# 3           3        1      1             4            1  2016-01-04
# 4           4        1      1             5            2  2016-01-05
#
#   UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME ORIGIN_STATE_ABR       ...        \
# 0             F9    MIA        Miami, FL               FL       ...
# 1             F9    LGA     New York, NY               NY       ...
# 2             F9    ATL      Atlanta, GA               GA       ...
# 3             F9    LGA     New York, NY               NY       ...
# 4             F9    MIA        Miami, FL               FL       ...
#
#   DEP_TIME_BLK CRS_ARR_TIME ARR_TIME ARR_DELAY ARR_DEL15  ARR_DELAY_GROUP  \
# 0    1300-1359         1635   1616.0     -19.0       0.0             -2.0
# 1    1700-1759         2057   2030.0     -27.0       0.0             -2.0
# 2    0600-0659          900    925.0      25.0       1.0              1.0
# 3    0900-0959         1235   1251.0      16.0       1.0              1.0
# 4    1300-1359         1630   1556.0     -34.0       0.0             -2.0
#
#    CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  DISTANCE  DISTANCE_GROUP
# 0             180.0                161.0    1096.0               5
# 1             212.0                183.0    1096.0               5
# 2             130.0                137.0     762.0               4
# 3             175.0                163.0     762.0               4
# 4             190.0                157.0    1096.0               5
#
# [5 rows x 30 columns]

# %%
data = data[data['DEP_DELAY'] < 300]

# %%
print("There are {} entries and {} columns in the flight data"\
      .format(data.shape[0], data.shape[1]))
# Out:
# There are 479820 entries and 30 columns in the flight data

# %%
data['DEP_DELAY'] = np.maximum(data['DEP_DELAY'], -30)

# %% [markdown]
# ## Create color maps

# %%
states = data.groupby('ORIGIN_STATE_ABR')['ARR_DELAY'].mean()

# %%
import plotly
plotly.tools.set_credentials_file(username='dimopc', api_key='ez21AYJUPVwaw1XBLjvf')

# %%
import plotly.plotly as py

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

    
df['arrival']=np.zeros(df.shape[0])
for i in range(df['code'].shape[0]):
    if df['code'][i] in states.keys():
        df['arrival'][i] = states[df['code'][i]]
    else:
        df['arrival'][i] = 0
        
departures = data.groupby('ORIGIN_STATE_ABR')['DEP_DELAY'].mean()
df['departure']=np.zeros(df.shape[0])
for i in range(df['code'].shape[0]):
    if df['code'][i] in departures.keys():
        df['departure'][i] = departures[df['code'][i]]
    else:
        df['departure'][i] = 0
        
df['text'] = df['state'] + '<br>' +\
    'Beef '+df['beef']+' Dairy '+df['dairy']+'<br>'+\
    'Fruits '+df['total fruits']+' Veggies ' + df['total veggies']+'<br>'+\
    'Wheat '+df['wheat']+' Corn '+df['corn']
# Out:
# C:\Users\chris\Anaconda3\envs\mlp\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\Anaconda3\envs\mlp\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\Anaconda3\envs\mlp\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\Anaconda3\envs\mlp\lib\site-packages\ipykernel\__main__.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_plot = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = df['departure'],
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Minutes")
        ) ]

layout = dict(
        title = 'New York Flights Departure Delay Average, US 2016',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'), )

# %%
fig = dict( data=data_plot, layout=layout )
py.plot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~dimopc/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# 'https://plot.ly/~dimopc/0'

# %%
# Out:
# C:\Users\chris\Anaconda3\envs\mlp\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\Anaconda3\envs\mlp\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## What's going on to Wyoming?

# %%
check = data[data['ORIGIN_STATE_ABR']== 'WY']

# %%
check.describe()
# Out:
#           Unnamed: 0    QUARTER      MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# count      10.000000  10.000000  10.000000     10.000000         10.0
# mean   159175.400000   1.600000   4.300000     16.500000          6.0
# std    167190.982347   1.264911   4.110961      8.501634          0.0
# min     25039.000000   1.000000   1.000000      2.000000          6.0
# 25%     63486.000000   1.000000   2.000000     12.250000          6.0
# 50%    105858.000000   1.000000   3.000000     18.000000          6.0
# 75%    111762.000000   1.000000   3.000000     23.000000          6.0
# max    472982.000000   4.000000  12.000000     27.000000          6.0
#
#        CRS_DEP_TIME     DEP_TIME    DEP_DELAY  DEP_DEL15  DEP_DELAY_GROUP  \
# count     10.000000    10.000000    10.000000  10.000000        10.000000
# mean    1243.400000  1226.300000   138.900000   0.500000         2.500000
# std       45.346077   217.834315   344.789936   0.527046         4.196559
# min     1205.000000   659.000000    -3.000000   0.000000        -1.000000
# 25%     1208.750000  1222.250000     8.500000   0.000000         0.000000
# 50%     1225.000000  1234.000000    16.000000   0.500000         0.500000
# 75%     1287.250000  1324.500000    71.250000   1.000000         4.000000
# max     1308.000000  1502.000000  1114.000000   1.000000        12.000000
#
#        CRS_ARR_TIME    ARR_TIME    ARR_DELAY  ARR_DEL15  ARR_DELAY_GROUP  \
# count     10.000000    10.00000    10.000000  10.000000        10.000000
# mean    1855.700000  1853.30000   145.600000   0.700000         2.900000
# std       45.023574   196.18758   348.805645   0.483046         3.842742
# min     1815.000000  1340.00000    -3.000000   0.000000        -1.000000
# 25%     1819.500000  1831.75000     8.250000   0.250000         0.250000
# 50%     1838.000000  1890.00000    33.000000   1.000000         1.500000
# 75%     1900.750000  1943.00000    78.750000   1.000000         4.750000
# max     1919.000000  2043.00000  1134.000000   1.000000        12.000000
#
#        CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  DISTANCE  DISTANCE_GROUP
# count         10.000000            10.000000      10.0            10.0
# mean         252.300000           259.000000    1894.0             8.0
# std            3.591657            27.133415       0.0             0.0
# min          250.000000           221.000000    1894.0             8.0
# 25%          250.000000           244.250000    1894.0             8.0
# 50%          251.000000           249.000000    1894.0             8.0
# 75%          252.500000           274.250000    1894.0             8.0
# max          261.000000           309.000000    1894.0             8.0

# %%
check['DEP_DELAY']
# Out:
# 24999        1.0
# 60686      114.0
# 62618       27.0
# 65260       -3.0
# 104277      86.0
# 106775      21.0
# 109342      11.0
# 112109       8.0
# 469211    1114.0
# 471464      10.0
# Name: DEP_DELAY, dtype: float64

# %%
check['ARR_DELAY']
# Out:
# 24999       -3.0
# 60686       84.0
# 62618       21.0
# 65260       41.0
# 104277      85.0
# 106775      25.0
# 109342       4.0
# 112109       2.0
# 469211    1134.0
# 471464      63.0
# Name: ARR_DELAY, dtype: float64

# %%
check_ar = data[data['ORIGIN_STATE_ABR']== 'AR']

# %%
check_ar
# Out:
#         Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 150729      151180        2      4             8            5  2016-04-08
# 150730      151181        2      4            24            7  2016-04-24
# 150731      151182        2      4            15            5  2016-04-15
# 150732      151183        2      4            11            1  2016-04-11
# 150733      151184        2      4             6            3  2016-04-06
# 150734      151185        2      4            17            7  2016-04-17
# 150735      151186        2      4            19            2  2016-04-19
# 150736      151187        2      4            13            3  2016-04-13
# 150737      151188        2      4            10            7  2016-04-10
# 150738      151189        2      4            25            1  2016-04-25
# 150739      151190        2      4            27            3  2016-04-27
# 150740      151191        2      4            12            2  2016-04-12
# 150741      151192        2      4            20            3  2016-04-20
# 150742      151193        2      4             5            2  2016-04-05
# 150743      151194        2      4            14            4  2016-04-14
# 150744      151195        2      4            18            1  2016-04-18
# 150745      151196        2      4            29            5  2016-04-29
# 150746      151197        2      4            26            2  2016-04-26
# 150747      151198        2      4            28            4  2016-04-28
# 150748      151199        2      4            22            5  2016-04-22
# 150749      151200        2      4             7            4  2016-04-07
# 150750      151201        2      4            21            4  2016-04-21
# 196908      197456        2      5             3            2  2016-05-03
# 196909      197457        2      5            25            3  2016-05-25
# 196910      197458        2      5            26            4  2016-05-26
# 196911      197459        2      5            10            2  2016-05-10
# 196912      197460        2      5            27            5  2016-05-27
# 196913      197461        2      5             4            3  2016-05-04
# 196914      197462        2      5            11            3  2016-05-11
# 196915      197463        2      5             8            7  2016-05-08
# ...            ...      ...    ...           ...          ...         ...
# 437179      438567        4     11            20            7  2016-11-20
# 437180      438568        4     11            21            1  2016-11-21
# 437181      438569        4     11            22            2  2016-11-22
# 437182      438570        4     11            23            3  2016-11-23
# 437183      438571        4     11            26            6  2016-11-26
# 437184      438572        4     11            27            7  2016-11-27
# 437185      438573        4     11            28            1  2016-11-28
# 437630      439018        4     11            29            2  2016-11-29
# 437799      439188        4     11             1            2  2016-11-01
# 437800      439189        4     11             2            3  2016-11-02
# 437801      439190        4     11             3            4  2016-11-03
# 437802      439191        4     11             4            5  2016-11-04
# 437858      439247        4     11             1            2  2016-11-01
# 437859      439248        4     11             2            3  2016-11-02
# 437860      439249        4     11             3            4  2016-11-03
# 437182              0.0             173.0                184.0    1147.0
# 437183              0.0             173.0                174.0    1147.0
# 437184              0.0             172.0                188.0    1147.0
# 437185              5.0             172.0                153.0    1147.0
# 437630             10.0             173.0                149.0    1147.0
# 437799             -1.0             177.0                168.0    1147.0
# 437800             -2.0             177.0                166.0    1147.0
# 437801             -2.0             177.0                156.0    1147.0
# 437802              3.0             177.0                181.0    1147.0
# 437858             -1.0             166.0                154.0    1147.0
# 437859             -1.0             166.0                166.0    1147.0
# 437860             -1.0             166.0                163.0    1147.0
# 437861              8.0             166.0                166.0    1147.0
# 476988              0.0             173.0                177.0    1147.0
# 476989             -1.0             173.0                174.0    1147.0
# 476990             -2.0             173.0                152.0    1147.0
# 476991             -2.0             170.0                158.0    1147.0
# 476992             -2.0             170.0                156.0    1147.0
# 476993             -2.0             173.0                156.0    1147.0
# 476994              1.0             173.0                157.0    1147.0
# 476995              4.0             173.0                154.0    1147.0
# 476996             -2.0             173.0                160.0    1147.0
# 476997              1.0             173.0                158.0    1147.0
# 476998             -2.0             170.0                152.0    1147.0
# 476999             -2.0             173.0                159.0    1147.0
# 477000             12.0             173.0                155.0    1147.0
# 477001              1.0             173.0                169.0    1147.0
#
#         DISTANCE_GROUP
# 150729               5
# 150730               5
# 150731               5
# 150732               5
# 150733               5
# 150734               5
# 150735               5
# 150736               5
# 150737               5
# 150738               5
# 150739               5
# 150740               5
# 150741               5
# 150742               5
# 150743               5
# 150744               5
# 150745               5
# 150746               5
# 150747               5
# 150748               5
# 150749               5
# 150750               5
# 196908               5
# 196909               5
# 196910               5
# 196911               5
# 196912               5
# 196913               5
# 196914               5
# 196915               5
# ...                ...
# 437179               5
# 437180               5
# 437181               5
# 437182               5
# 437183               5
# 437184               5
# 437185               5
# 437630               5
# 437799               5
# 437800               5
# 437801               5
# 437802               5
# 437858               5
# 437859               5
# 437860               5
# 437861               5
# 476988               5
# 476989               5
# 476990               5
# 476991               5
# 476992               5
# 476993               5
# 476994               5
# 476995               5
# 476996               5
# 476997               5
# 476998               5
# 476999               5
# 477000               5
# 477001               5
#
# [242 rows x 30 columns]

# %% [markdown]
# # Seasonal Plots

# %%
days_del = data.groupby('DAY_OF_MONTH')['DEP_DELAY'].mean()

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,32), days_del,  align='center',color='b')
plt.xticks(np.arange(1,32), np.arange(1,32))
plt.title('Average Day of Month Delay')
plt.xlabel('Day of Month')
plt.ylabel('Average Minutes Departure Delay')
plt.xlim([0,32])
plt.grid(True)
plt.show()

# %%
week_del = data.groupby('DAY_OF_WEEK')['DEP_DELAY'].mean()

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,8), week_del,  align='center')
plt.xticks(np.arange(1,8), ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title('Average Day of Week Delay')
plt.xlabel('Day of Week')
plt.ylabel('Average Minutes Departure Delay')
plt.grid(True)
plt.show()

# %%
months_del = data.groupby('MONTH')['DEP_DELAY'].mean()

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,13), months_del,  align='center')
plt.xticks(np.arange(1,13), ['January','February','March','April','May','June','July','August','September','October','November','December'],rotation='vertical')
plt.title('Average Monthly Delay')
plt.xlabel('Month')
plt.ylabel('Average Minutes Departure Delay')
plt.xlim([0,13])
plt.grid(True)
plt.show()

# %%
month_del = data.groupby('MONTH')['DEP_DELAY'].count()

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,13), month_del,  align='center')
plt.xticks(np.arange(1,13), ['January','February','March','April','May','June','July','August','September','October','November','December'])
plt.title('Average Monthly Delay')
plt.xlabel('Month')
plt.ylabel('Average Minutes Departure Delay')

# %%
time = data.groupby('DEP_TIME_BLK')['DEP_DELAY'].mean()

# %%
keys = list(time.keys())

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,20), time,  align='center')
plt.xticks(np.arange(1,20), keys, rotation='vertical')
plt.title('Hourly Average Delay')
plt.xlabel('Time Frame')
plt.ylabel('Average Minutes Departure Delay')
plt.xlim([0,20])
plt.grid(True)
plt.show()

# %%
carrier = data.groupby('UNIQUE_CARRIER')['ARR_DELAY'].mean()

# %%
keys = list(carrier.keys())

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,13), carrier,  align='center')
plt.xticks(np.arange(1,13), keys, rotation='vertical')
plt.title('Average Delay by Unique Carrier')
plt.xlabel('Unique Carriers')
plt.ylabel('Average Minutes Arrival Delay')
plt.xlim([0,13])
plt.grid(True)
plt.show()

# %%
dest = data.groupby('DEP_TIME_BLK')['ARR_DELAY'].mean()

# %%
dest
# Out:
# DEST
# ABQ     2.595016
# ACK     3.625641
# ALB     2.454840
# ATL    -3.042108
# AUS     3.480315
# AVL   -23.666667
# BGM     5.471198
# BGR     9.517949
# BHM    13.658000
# BNA     0.076105
# BOS     4.898834
# BQN     7.083164
# BTV     6.058540
# BUF     3.211558
# BUR     2.323944
# BWI    -3.253706
# BZN     4.125000
# CAE    11.115681
# CHO    15.596154
# CHS     0.632184
# CLE     4.506633
# CLT    -1.119969
# CMH     8.829493
# CVG     4.058824
# DAB    -0.759207
# DAL     0.362347
# DCA     7.552318
# DEN    -1.745618
# DFW    -2.108923
# DTW    -2.056950
#          ...
# PHX    -2.489369
# PIT    10.234657
# PSE     9.394286
# PSP     5.007143
# PWM     9.285501
# RDU     7.168350
# RIC    11.637703
# RNO     2.336700
# ROC     3.193131
# RSW    -0.232842
# SAN    -3.506317
# SAT     1.108824
# SAV     5.811996
# SDF    17.082305
# SEA    -0.587923
# SFO     0.996483
# SJC     4.794562
# SJU     2.582533
# SLC    -1.948485
# SMF     9.653125
# SRQ     9.309654
# STL     3.597855
# STT     2.392661
# SWF    12.208683
# SYR     4.777933
# TPA     1.383724
# TUS    -1.511364
# TVC    31.687500
# TYS    15.352941
# XNA    12.919355
# Name: ARR_DELAY, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.bar(np.arange(1,13), carrier,  align='center')
plt.xticks(np.arange(1,13), keys, rotation='vertical')
plt.title('Hourly Average Delay')
plt.xlabel('Time Frame')
plt.ylabel('Average Minutes Departure Delay')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b8465f14c345> in <module>()
#       1 plt.figure(figsize=(12,6))
#       2 plt.bar(np.arange(1,13), carrier,  align='center')
# ----> 3 plt.xticks(np.arange(1,13), keys, rotation='vertical')
#       4 plt.title('Hourly Average Delay')
#       5 plt.xlabel('Time Frame')
#
# NameError: name 'keys' is not defined
